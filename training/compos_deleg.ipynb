# %%
# abc try
import math
from abc import ABC, abstractmethod

# automate __repr__, handles strucutral changes automatically, __str__ must be manually crafted for orchestrator classes like tunnelsection

class Rockmass(ABC):

    def __init__(self, ucs, fa, name=None):
        self.ucs=ucs
        self.fa=fa
        self.name=name or self.__class__.__name__

    @property
    @abstractmethod
    def fa(self) -> float:
        """Force subclass to return its specific backing store."""
        pass

    @fa.setter
    @abstractmethod
    def fa(self, value):
        """Centralized Forensic Audit: All friction angles must be physically possible."""
        if not (0 <= value <= 90):
            raise ValueError("Physics Breach: Friction angle must be between 0 and 90.")
        #self._fa = value; not this because abc class is not store

    @abstractmethod
    def estimated_strength(self, **kwargs):

        confinement = kwargs.get('confinement')

        k = (1 + math.sin(math.radians(self.fa))) / (1 - math.sin(math.radians(self.fa)))
        return self.ucs + (k * confinement) #type: ignore
    # basically all rockmass must have these logic same

    def __str__(self):
        """User representation"""
        return f"{self.name} | UCS: {self.ucs} MPa | FA: {self.fa}°"

# k, v cuz its dictionary value pair
    def __repr__(self):
        """Developer/Forensic representation."""
        active = [f"{k.lstrip('_')}={v!r}" for k, v in vars(self).items() if v is not None]
        return f"{self.__class__.__name__}({', '.join(active)})"



class Hrock(Rockmass):
    """himalayan rock"""

    def __init__(self, ucs, fa, fd, name=None):
        self._fa = None
        super().__init__(ucs, fa, name=name)
        self.fd = fd


    @property
    def fa(self) -> float:
        return self._fa #type:ignore

    @fa.setter
    def fa(self,value):

        Rockmass.fa.fset(self, value) #type: ignore
        self._fa = value

    def estimated_strength(self, **kwargs):

        base_str = super().estimated_strength(**kwargs)
        stress_dir = kwargs.get('stress_dir')

        if stress_dir is not None and abs(stress_dir-self.fd)<=10:
            updated_base_str = base_str*0.68
            return updated_base_str
        return base_str

    def __repr__(self):
        #return super().__repr__()
        """Override to include Himalayan-specific 'fd'."""
        active = [f"{k.lstrip('_')}={v!r}" for k, v in vars(self).items() if v is not None]
        return f"{self.__class__.__name__}({', '.join(active)})"

    def __str__(self):
        """User representation"""
    # Logic: Convert '_fa' -> 'Fa' or 'cost_per_m' -> 'Cost Per M'
        return f"{super().__str__()} | Foliation: {self.fd}°"




shale = Hrock(18, 18, 180)  #180 on fa raise ValueError good
print(repr(shale))
# Out:
# Hrock(fa=18, ucs=18, name='Hrock', fd=180)

# %%
# to have an object that is something of class1 class2 and not entirely a single class

class TunnelSupport:
    """Different tunnel supports for different rockclass requiring different financial costs"""

    def __init__(self, cost_per_m: float, **kwargs ):
        shotcrete_thickness = kwargs.get('shotcrete_thickness')
        self.shotcrete_thickness=shotcrete_thickness
        bolt_length = kwargs.get('bolt_length')
        self.bolt_length = bolt_length
        self.cost_per_m = cost_per_m

    def __repr__(self):

        active = [f"{k.lstrip('_')}={v!r}" for k, v in vars(self).items() if v is not None]
        return f"{self.__class__.__name__}({', '.join(active)})"

    def __str__(self):
       # Logic: Convert '_bolt_length' -> 'Bolt Length' and filter out empty attributes
        report = [
            f"{k.lstrip('_').replace('_', ' ').title()}: {v}"
            for k, v in vars(self).items()
            if v is not None and k != 'name'
        ]
        return f"SUPPORT | {' | '.join(report)}"

class TunnelSection():
    def __init__(self, section_id: str, geology: Hrock, support: TunnelSupport, fos):
        self.section_id = section_id
        self.geology = geology # a hrock obj
        self.support =support #tunnelsupport obj
        self.fos = fos


    def calculate_risk_factor(self):
        # delegation; asking geology obj for its data

        strength = self.geology.estimated_strength(confinement=0, stress_dir=90)
        if strength<50:
            return "Low Risk"
        return "High Risk"

    def total_cost(self, length):
        return self.support.cost_per_m * length

# !r for forcing the recursive call of __repr__ nested objects instead of __str__
    def __repr__(self):
        active = [f"{k.lstrip('_')}={v!r}" for k, v in vars(self).items() if v is not None]
        return f"{self.__class__.__name__}({', '.join(active)})"
    # so every parent like geology = rockmass and support = Tunnelsupport must have repr to full define them

    def __str__(self):
            return (
            f"--- SECTION REPORT: {self.section_id} ---\n"
            f"  GEOLOGY: {self.geology}\n"
            f"  SUPPORT: {self.support}\n"
            f"  STATUS:  {self.calculate_risk_factor()}"
        )

    def implement_fos(self):
         return pow(2, self.fos)

# it only takes two arguements
# add is only useful when the objects possess data required for the operationas internally, not extenrally like self.total_cost(length)

    def __call__(self, length):
            return self.total_cost(length)

    def __add__(self, other):
        """Signals Python to look elsewhere or fail if objects are added directly."""
        #return NotImplemented
        return self.implement_fos() + other.implement_fos()

# add dunder is used to add OBJECTS  not results of the objects and as such
# for using params during call, use call
# to use add we must provide the length in the init method itself

# %%
# Create the Parts
granite = Hrock(ucs=150, fa=45, fd=45)
shale = Hrock(ucs=111, fa=41, fd=41)
steel_ribs = TunnelSupport(shotcrete_thickness=None, bolt_length=20, cost_per_m=5000)
schist = Hrock(ucs=200, fa = 60, fd = 67)
shotcrete = TunnelSupport(shotcrete_thickness=200, bolt_length=None, cost_per_m=1000)


# Assemble the System

section_1 = TunnelSection("Chainage 0+000", geology=granite, support=steel_ribs, fos = 4)
section_2 = TunnelSection("Chainage0+500", geology=schist, support = shotcrete, fos=2)

#print(repr(section_1))

tunnel_sections = [section_1, section_2]




section_3 = TunnelSection(section_id='Chainage 0+000', geology=Hrock(fa=45, ucs=150, name='Hrock', fd=45), support=TunnelSupport(bolt_length=20, cost_per_m=5001), fos=4)


tunnel_sections = [section_1, section_2, section_3]


#for sections in tunnel_sections:
   # print(sections.total_cost(20))

rock_list = [granite, shale]
#print(rock_list)

# tried to implement add but used call instead
#print(section_1(length=20)+section_2(length=20)) #type:ignore

print(section_1+section_2) # 2^4 + 2^2
# Out:
# 20

# %%
class Engine():
    def __init__(self, horsepower):
        self.horsepower = horsepower

class DrillBit():
    def __init__(self, diameter):
        self.diameter = diameter

class DrillRig():

    def __init__(self, engine: Engine, bit: DrillBit):
        self.engine = engine
        self.bit = bit

    def power_density(self):
        return self.engine.horsepower/self.bit.diameter
