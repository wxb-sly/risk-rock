# %%
# abc try

from abc import ABC, abstractmethod

class Rockmass(ABC):

    def __init__(self, ucs, fa):
        self.ucs=ucs
        self.fa=fa


    @property
    @abstractmethod
    def fa(self):
        pass

    @fa.setter
    @abstractmethod
    def fa(self, value):
        pass
        #self._fa = value


class Hrock(Rockmass):
    """himalayan rock"""

    def __init__(self, ucs, fa, fd):
        super().__init__(ucs, fa)
        self.fd = fd


    @property
    def fa(self):
        return self._fa

    @fa.setter
    def fa(self,value):
        if not (0 <= value <= 90):
            raise ValueError("Physics Breach")
        self._fa = value

#shale = Hrock(18, 18, 180)  #180 on fa raise ValueError good
